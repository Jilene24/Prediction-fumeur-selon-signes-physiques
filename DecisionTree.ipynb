# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Définir les meilleurs paramètres pour l'arbre de décision
best_params = {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}

# Initialiser le classifieur d'arbre de décision avec les meilleurs paramètres
clf = DecisionTreeClassifier(**best_params)

# Entraîner le modèle avec les données d'entraînement (X_train, y_train)
clf.fit(X_train, y_train)

# Tracer l'arbre de décision
plt.figure(figsize=(20, 10))
plot_tree(clf, filled=True, feature_names=X_train.columns)
plt.show()
